# %%
import perspective as per
from perspective.widget import PerspectiveWidget

table = per.table({"a": [1,2,3]})

widget = PerspectiveWidget(table)
widget
# Out:
# PerspectiveWidget(binding_mode='server', columns=['a'], table_name='rHgue7Q7jpi-VuIQPeIqM', theme=None)

# %%
widget.settings = False
